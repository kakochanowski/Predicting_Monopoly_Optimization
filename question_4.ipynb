# %%
library(gtools)
library(dplyr)
library(ggplot2)

# %%
# load data
inTeams<-read.csv("https://projects.fivethirtyeight.com/soccer-api/club/spi_global_rankings.csv")

# %%
# PRE SIMULATION WORK

# %%
# Prize dataframe
ranks <- 1:20
prizes <- matrix(ranks, nrow=20, ncol=1, byrow=FALSE)
prizes <- as.data.frame(prizes)
colnames(prizes) <- c('team_rank')
prizes$prize <- c(225,210,200,190,160,150,140,125,123,120,118,115,112,110,108,105,100,52,50,49)

# %%
# taking averages
mean.off<-mean(inTeams$off)
mean.def<-mean(inTeams$def)
lmean.off<-mean(log(inTeams$off))
lmean.def<-mean(log(inTeams$def)) 

# subset to premier league
premLeague<-subset(inTeams,league=="Barclays Premier League")
premTeams<-premLeague$name
rownames(premLeague)<-premTeams
df.prem<-premLeague[,c("off","def")]

# build parameters
lmean.def<- log(mean(df.prem$def))
lmean.off<- log(mean(df.prem$off))               
df.prem["alpha"]<-log(df.prem["off"])-lmean.def
df.prem["delta"]<-lmean.off-log(df.prem["def"])
alphaList<-df.prem$alpha
deltaList<-df.prem$delta
names(alphaList)<-rownames(df.prem)
names(deltaList)<-rownames(df.prem)

# %%
df.prem.matrix.added1<- as.matrix(df.prem)
for (i in 1) {
    df.prem.matrix.added[i,1]= df.prem.matrix.added1[i,1]*1.10
    print(df.prem.matrix.added1[i,1])
    }
df.prem.matrix.added1
# Out:
# [1] 2.9
#                          off  def  alpha     delta
# Manchester City          2.90 0.20 1.3835395 2.3108012
# Liverpool                2.92 0.25 1.3904124 2.0876577
# Chelsea                  2.39 0.29 1.1901222 1.9392377
# Arsenal                  2.16 0.46 1.0889370 1.4778921
# Tottenham Hotspur        2.36 0.65 1.1774904 1.1321463
# Manchester United        2.19 0.67 1.1027303 1.1018409
# Aston Villa              1.99 0.63 1.0069634 1.1633988
# West Ham United          2.02 0.73 1.0219263 1.0160741
# Brighton and Hove Albion 1.85 0.62 0.9340144 1.1793991
# Crystal Palace           1.89 0.69 0.9554056 1.0724270
# Wolverhampton            1.73 0.61 0.8669502 1.1956597
# Southampton              1.94 0.89 0.9815168 0.8178972
# Leicester City           2.04 1.00 1.0317786 0.7013633
# Brentford                1.80 0.85 0.9066155 0.8638823
# Newcastle                1.75 0.82 0.8784446 0.8998143
# Burnley                  1.62 0.83 0.8012550 0.8876929
# Everton                  1.70 0.93 0.8494571 0.7739340
# Leeds United             1.92 1.15 0.9711540 0.5616014
# Watford                  1.65 1.08 0.8196041 0.6244023
# Norwich City             1.51 1.19 0.7309385 0.5274100

# %%
df.prem.matrix.conceded1<- as.matrix(df.prem)
for (i in 1) {
    df.prem.matrix.conceded1[i,2]= df.prem.matrix.conceded1[i,2]*.9
    print(df.prem.matrix.conceded1[i,2])
    }
df.prem.matrix.conceded1
# Out:
# [1] 0.18
#                          off  def  alpha     delta
# Manchester City          2.90 0.18 1.3835395 2.3108012
# Liverpool                2.92 0.25 1.3904124 2.0876577
# Chelsea                  2.39 0.29 1.1901222 1.9392377
# Arsenal                  2.16 0.46 1.0889370 1.4778921
# Tottenham Hotspur        2.36 0.65 1.1774904 1.1321463
# Manchester United        2.19 0.67 1.1027303 1.1018409
# Aston Villa              1.99 0.63 1.0069634 1.1633988
# West Ham United          2.02 0.73 1.0219263 1.0160741
# Brighton and Hove Albion 1.85 0.62 0.9340144 1.1793991
# Crystal Palace           1.89 0.69 0.9554056 1.0724270
# Wolverhampton            1.73 0.61 0.8669502 1.1956597
# Southampton              1.94 0.89 0.9815168 0.8178972
# Leicester City           2.04 1.00 1.0317786 0.7013633
# Brentford                1.80 0.85 0.9066155 0.8638823
# Newcastle                1.75 0.82 0.8784446 0.8998143
# Burnley                  1.62 0.83 0.8012550 0.8876929
# Everton                  1.70 0.93 0.8494571 0.7739340
# Leeds United             1.92 1.15 0.9711540 0.5616014
# Watford                  1.65 1.08 0.8196041 0.6244023
# Norwich City             1.51 1.19 0.7309385 0.5274100

# %%
Added ten percent to first
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:7: unexpected symbol
# 1: Added ten
#           ^
# Traceback:

# %%
df.prem.matrix.added1<- as.matrix(df.prem)
for (i in 1) {
    df.prem.matrix.added1[i,1]= df.prem.matrix.added1[i,1]*1.10
    print(df.prem.matrix.added1[i,1])
    }
df.prem.matrix.added1
# simulate score line for a match
draw.score<-function(team1,team2){
    c(
        rpois(1,exp(alphaList[team1]-deltaList[team2])),
  rpois(1,exp(alphaList[team2]-deltaList[team1]))
    )
}
draw.score("Liverpool","Arsenal")
# All possible matches in a season
allMatches<-permutations(20, 2, v=rownames(df.prem.matrix.added),repeats.allowed=FALSE)
colnames(allMatches)<-c("home","away")
allMatches
nrow(allMatches)

SeasonSim <- function(allMatches){
     ScoresMatrix <- matrix(nrow=nrow(allMatches),  ncol=4)
        for (ii in 1:nrow(allMatches)  ) {
         ScoresMatrix[ii,1:2]=allMatches[ii,]
         ScoresMatrix[ii,3:4]= as.numeric(draw.score(allMatches[ii,"home"],allMatches[ii,"away"] ))
        }
        colnames(ScoresMatrix)<-c("home.team","away.team","home.score","away.score")
        ScoresMatrix <- as.data.frame(ScoresMatrix)
        ScoresMatrix$home.score <- as.numeric(ScoresMatrix$home.score)
        ScoresMatrix$away.score <- as.numeric(ScoresMatrix$away.score)  
        
        # PEPARING AGGREGATE STATS DFs
        df.points <- as.data.frame(ScoresMatrix)
        df.points_goalsfor <- as.data.frame(ScoresMatrix)
        df.points_goalsagainst <- as.data.frame(ScoresMatrix)
        name <- rownames(df.prem.matrix.added1)
        for (i in 1:20){
            df.points[, name[i]] <- 0
        }
        df.points

        # ASSIGNING POINTS PER MATCH
        for (i in 1:380){ 
            for (j in 1:20){
                if (df.points[i,1] == name[j]){
                    if (df.points[i,3] > df.points[i,4]){
                        df.points[i,j+4] = 3
                    } else if (df.points[i,3] == df.points[i,4]){
                        df.points[i,j+4] = 1
                    } else if (df.points[i,3] < df.points[i,4]){
                        df.points[i,j+4] = 0
                    } 
                } 
                if (df.points[i,2] == name[j]){
                    if (df.points[i,3] > df.points[i,4]){
                        df.points[i,j+4] = 0
                    } else if (df.points[i,3] == df.points[i,4]){
                        df.points[i,j+4] = 1
                    } else if (df.points[i,3] < df.points[i,4]){
                        df.points[i,j+4] = 3
                    }      
                }
            }   
        } 
    
        # PREPARING DFs
        for (i in 1:20){
            df.points_goalsfor[, name[i]] <- 0
        }
        for (i in 1:20){
            df.points_goalsagainst[, name[i]] <- 0
        }
    
        # GOALS FOR
        for (i in 1:380){
            for (j in 1:20){
                if (df.points_goalsfor[i,1] == name[j]){ # looking at home team
                    df.points_goalsfor[i,j+4] = df.points_goalsfor[i,3]  # home points go to goals for
                }
                if (df.points_goalsfor[i,2] == name[j]){ # looking at away team
                    df.points_goalsfor[i,j+4] = df.points_goalsfor[i,4] # away points go to goals for
                }
            }
        }
    
        # GOALS AGAINST
        for (i in 1:380){
            for (j in 1:20){
                if (df.points_goalsagainst[i,1] == name[j]){ # looking at home team
                    df.points_goalsagainst[i,j+4] = df.points_goalsagainst[i,4]  # home points go to goals for
                }
                if (df.points_goalsagainst[i,2] == name[j]){ # looking at away team
                    df.points_goalsagainst[i,j+4] = df.points_goalsagainst[i,3] # away points go to goals for
                }
            }
        } 
        
        # AGGREGATING POINTS and GOALS
        points <- df.points[,c(-1,-2,-3,-4)]
        points <- sapply(points, as.numeric)
        points_sum <- as.data.frame(colSums(points))
        
        goalsfor <- df.points_goalsfor[,c(-1,-2,-3,-4)]
        goalsfor <- sapply(goalsfor, as.numeric)
        goalsfor_sum <- as.data.frame(colSums(goalsfor))
    
        goalsagainst <- df.points_goalsagainst[,c(-1,-2,-3,-4)]
        goalsagainst <- sapply(goalsagainst, as.numeric)
        goalsagainst_sum <- as.data.frame(colSums(goalsagainst))

        # MERGE TO ONE DF
        df.teams <- cbind(points_sum, goalsfor_sum, goalsagainst_sum)
        colnames(df.teams)[1] <- 'points'
        colnames(df.teams)[2] <- 'goals_for'
        colnames(df.teams)[3] <- 'goals_against'
        df.teams$team_names <- row.names(df.teams)
    
        # ADD TIE BREAKER VARIABLES
        df.teams <- df.teams %>%
            mutate(net_goals = goals_for - goals_against) %>%
            mutate(tie_breaker = runif(20, 0, 1))
        df.teams1 <- df.teams
        df.teams1$temp_team_rank <- rank(desc(df.teams1$points))
        df.teams1$temp_team_rank2 <- rank(desc(df.teams1$points))
        df.teams1$goals_rank <- rank(desc(df.teams1$net_goals))
        df.teams1$goalsfor_rank <- rank(desc(df.teams1$goals_for))
        df.teams1
    
        # RANK 
        for (ii in 1:nrow(df.teams1)){
            for (jj in 1:nrow(df.teams1)){
                if (ii != jj & df.teams1[ii,7] == df.teams1[jj,7]){
                    if (df.teams1[ii,9] > df.teams1[jj,9]){ #goals rank
                        df.teams1[ii,8] = df.teams1[ii,8]+0.5
                        df.teams1[jj,8] = df.teams1[jj,8]-0.5
                    } else if (df.teams1[ii,9] == df.teams1[jj,9]){ 
                        if (df.teams1[ii,10] > df.teams1[jj,10]){ #goals_for rank
                            df.teams1[ii,8] = df.teams1[ii,8]+0.5
                            df.teams1[jj,8] = df.teams1[jj,8]-0.5
                        } else if (df.teams1[ii,10] == df.teams1[jj,10]){                   
                            if (df.teams1[ii,6] > df.teams1[jj,6]){
                            df.teams1[ii,8] = df.teams1[ii,8]+0.5
                            df.teams1[jj,8] = df.teams1[jj,8]-0.5
                            }   
                        }
                    }
                }
            }
        }
        df.teams1$team_rank <- rank(df.teams1$temp_team_rank2)
        
         # ASSIGN PRIZE
        df.earnings <- left_join(df.teams1, prizes, by=c("team_rank"))
        df.earnings
    }

SeasonSim(allMatches)

# results df
finalcol <- c("points", "goals_for", "goals_against", "team_names", "net_goals", "tie_breaker", "team_rank", "goals_rank", "goalsfor_rank", "prize")
df.final.output1 <- as.data.frame(matrix(ncol = length(finalcol), nrow=0, dimnames = list(NULL,finalcol)))

# simulations
nsims <- 100

# simulation
for (rep in 1:nsims) {
    df.sim.earnings <- SeasonSim(allMatches)
    df.sim.earnings$sim <- rep
    df.final.output1 <- rbind(df.final.output1, df.sim.earnings)
}
df.final.output1
# Out:
# [1] 3.19
#                          off  def  alpha     delta
# Manchester City          3.19 0.20 1.3835395 2.3108012
# Liverpool                2.92 0.25 1.3904124 2.0876577
# Chelsea                  2.39 0.29 1.1901222 1.9392377
# Arsenal                  2.16 0.46 1.0889370 1.4778921
# Tottenham Hotspur        2.36 0.65 1.1774904 1.1321463
# Manchester United        2.19 0.67 1.1027303 1.1018409
# Aston Villa              1.99 0.63 1.0069634 1.1633988
# West Ham United          2.02 0.73 1.0219263 1.0160741
# Brighton and Hove Albion 1.85 0.62 0.9340144 1.1793991
# Crystal Palace           1.89 0.69 0.9554056 1.0724270
# Wolverhampton            1.73 0.61 0.8669502 1.1956597
# Southampton              1.94 0.89 0.9815168 0.8178972
# Leicester City           2.04 1.00 1.0317786 0.7013633
# Brentford                1.80 0.85 0.9066155 0.8638823
# Newcastle                1.75 0.82 0.8784446 0.8998143
# Burnley                  1.62 0.83 0.8012550 0.8876929
# Everton                  1.70 0.93 0.8494571 0.7739340
# Leeds United             1.92 1.15 0.9711540 0.5616014
# Watford                  1.65 1.08 0.8196041 0.6244023
# Norwich City             1.51 1.19 0.7309385 0.5274100
# [1] 1 1
#       home            away
#  [1,] Arsenal         Aston Villa
#  [2,] Arsenal         Brentford
#  [3,] Arsenal         Brighton and Hove Albion
#  [4,] Arsenal         Burnley
#  [5,] Arsenal         Chelsea
#  [6,] Arsenal         Crystal Palace
#  [7,] Arsenal         Everton
#  [8,] Arsenal         Leeds United
#  [9,] Arsenal         Leicester City
# [10,] Arsenal         Liverpool
# [11,] Arsenal         Manchester City
# [12,] Arsenal         Manchester United
# [13,] Arsenal         Newcastle
# [14,] Arsenal         Norwich City
# [15,] Arsenal         Southampton
# [16,] Arsenal         Tottenham Hotspur
# [17,] Arsenal         Watford
# [18,] Arsenal         West Ham United
# [19,] Arsenal         Wolverhampton
# [20,] Aston Villa     Arsenal
# [21,] Aston Villa     Brentford
# [22,] Aston Villa     Brighton and Hove Albion
# [23,] Aston Villa     Burnley
# [24,] Aston Villa     Chelsea
# [25,] Aston Villa     Crystal Palace
# [26,] Aston Villa     Everton
# [27,] Aston Villa     Leeds United
# [28,] Aston Villa     Leicester City
# [29,] Aston Villa     Liverpool
# [30,] Aston Villa     Manchester City
# [31,] ⋮               ⋮
# [32,] West Ham United Leeds United
# [33,] West Ham United Leicester City
# [34,] West Ham United Liverpool
# [35,] West Ham United Manchester City
# [36,] West Ham United Manchester United
# [37,] West Ham United Newcastle
# [38,] West Ham United Norwich City
# [39,] West Ham United Southampton
# [40,] West Ham United Tottenham Hotspur
# [41,] West Ham United Watford
# [42,] West Ham United Wolverhampton
# [43,] Wolverhampton   Arsenal
# [44,] Wolverhampton   Aston Villa
# [45,] Wolverhampton   Brentford
# [46,] Wolverhampton   Brighton and Hove Albion
# [47,] Wolverhampton   Burnley
# [48,] Wolverhampton   Chelsea
# [49,] Wolverhampton   Crystal Palace
# [50,] Wolverhampton   Everton
# [51,] Wolverhampton   Leeds United
# [52,] Wolverhampton   Leicester City
# [53,] Wolverhampton   Liverpool
# [54,] Wolverhampton   Manchester City
# [55,] Wolverhampton   Manchester United
# [56,] Wolverhampton   Newcastle
# [57,] Wolverhampton   Norwich City
# [58,] Wolverhampton   Southampton
# [59,] Wolverhampton   Tottenham Hotspur
# [60,] Wolverhampton   Watford
# [61,] Wolverhampton   West Ham United
# [1] 380
#    points goals_for goals_against team_names               net_goals
# 1  94     62        11            Manchester City           51
# 2  70     57        18            Liverpool                 39
# 3  74     39        13            Chelsea                   26
# 4  52     36        25            Arsenal                   11
# 5  58     38        28            Tottenham Hotspur         10
# 6  73     48        27            Manchester United         21
# 7  46     27        33            Aston Villa               -6
# 8  52     37        36            West Ham United            1
# 9  45     28        34            Brighton and Hove Albion  -6
# 10 59     31        28            Crystal Palace             3
# 11 56     38        32            Wolverhampton              6
# 12 59     47        39            Southampton                8
# 13 50     36        39            Leicester City            -3
# 14 37     30        49            Brentford                -19
# 15 49     34        44            Newcastle                -10
# 16 37     30        48            Burnley                  -18
# 17 41     25        39            Everton                  -14
# 18 22     32        65            Leeds United             -33
# 19 23     25        62            Watford                  -37
# 20 32     28        58            Norwich City             -30
#    tie_breaker temp_team_rank temp_team_rank2 goals_rank goalsfor_rank
# 1  0.14595919   1.0            1               1.0        1.0
# 2  0.50826075   4.0            4               2.0        2.0
# 3  0.25082423   2.0            2               3.0        5.0
# 4  0.61728844   9.5            9               5.0        9.5
# 5  0.84630309   7.0            7               6.0        6.5
# 6  0.07279724   3.0            3               4.0        3.0
# 7  0.42713323  13.0           13              12.5       18.0
# 8  0.06984258   9.5           10              10.0        8.0
# 9  0.32496558  14.0           14              12.5       16.5
# 10 0.35892481   5.5            6               9.0       13.0
# 11 0.39908491   8.0            8               8.0        6.5
# 12 0.85642147   5.5            5               7.0        4.0
# 13 0.20855593  11.0           11              11.0        9.5
# 14 0.30609413  16.5           17              17.0       14.5
# 15 0.99972877  12.0           12              14.0       11.0
# 16 0.79811028  16.5           16              16.0       14.5
# 17 0.14924414  15.0           15              15.0       19.5
# 18 0.92087061  20.0           20              19.0       12.0
# 19 0.03726227  19.0           19              20.0       19.5
# 20 0.40595610  18.0           18              18.0       16.5
#    team_rank prize
# 1   1        225
# 2   4        190
# 3   2        210
# 4   9        123
# 5   7        140
# 6   3        200
# 7  13        112
# 8  10        120
# 9  14        110
# 10  6        150
# 11  8        125
# 12  5        160
# 13 11        118
# 14 17        100
# 15 12        115
# 16 16        105
# 17 15        108
# 18 20         49
# 19 19         50
# 20 18         52
#      points goals_for goals_against team_names               net_goals
# 1    72     43        11            Manchester City           32
# 2    80     61        11            Liverpool                 50
# 3    69     43        15            Chelsea                   28
# 4    64     36        23            Arsenal                   13
# 5    67     52        37            Tottenham Hotspur         15
# 6    60     43        22            Manchester United         21
# 7    59     36        25            Aston Villa               11
# 8    46     29        35            West Ham United           -6
# 9    49     32        34            Brighton and Hove Albion  -2
# 10   58     32        26            Crystal Palace             6
# 11   52     32        32            Wolverhampton              0
# 12   44     35        41            Southampton               -6
# 13   35     37        51            Leicester City           -14
# 14   49     31        47            Brentford                -16
# 15   53     35        39            Newcastle                 -4
# 16   40     26        39            Burnley                  -13
# 17   26     29        64            Everton                  -35
# 18   30     32        57            Leeds United             -25
# 19   47     30        38            Watford                   -8
# 20   17     17        64            Norwich City             -47
# 21   82     47         6            Manchester City           41
# 22   85     57         9            Liverpool                 48
# 23   73     57        20            Chelsea                   37
# 24   63     41        24            Arsenal                   17
# 25   57     33        25            Tottenham Hotspur          8
# 26   52     37        38            Manchester United         -1
# 27   44     25        30            Aston Villa               -5
# 28   61     37        21            West Ham United           16
# 29   48     27        33            Brighton and Hove Albion  -6
# 30   52     37        31            Crystal Palace             6
# ⋮    ⋮      ⋮         ⋮             ⋮                        ⋮
# 1971 54     28        24            Wolverhampton              4
# 1972 27     27        61            Southampton              -34
# 1973 53     49        48            Leicester City             1
# 1974 56     33        35            Brentford                 -2
# 1975 38     27        42            Newcastle                -15
# 1976 67     51        43            Burnley                    8
# 1977 48     36        43            Everton                   -7
# 1978 41     32        59            Leeds United             -27
# 1979 32     31        56            Watford                  -25
# 1980 44     29        50            Norwich City             -21
# 1981 88     55        11            Manchester City           44
# 1982 86     59        11            Liverpool                 48
# 1983 70     42        15            Chelsea                   27
# 1984 79     58        21            Arsenal                   37
# 1985 51     38        37            Tottenham Hotspur          1
# 1986 45     30        34            Manchester United         -4
# 1987 44     25        30            Aston Villa               -5
# 1988 61     50        38            West Ham United           12
# 1989 57     43        40            Brighton and Hove Albion   3
# 1990 47     32        32            Crystal Palace             0
# 1991 46     29        30            Wolverhampton             -1
# 1992 44     40        58            Southampton              -18
# 1993 38     31        54            Leicester City           -23
# 1994 41     28        41            Brentford                -13
# 1995 51     38        46            Newcastle                 -8
# 1996 55     36        30            Burnley                    6
# 1997 30     34        57            Everton                  -23
# 1998 39     44        70            Leeds United             -26
# 1999 28     31        59            Watford                  -28
# 2000 32     34        63            Norwich City             -29
#      tie_breaker temp_team_rank temp_team_rank2 goals_rank goalsfor_rank
# 1    0.37053995   2.0            2               2.0        4.0
# 2    0.56489621   1.0            1               1.0        1.0
# 3    0.70579397   3.0            3               3.0        4.0
# 4    0.12135418   5.0            5               6.0        7.5
# 5    0.99178114   4.0            4               5.0        2.0
# 6    0.98026954   6.0            6               4.0        4.0
# 7    0.24671993   7.0            7               7.0        7.5
# 8    0.35721226  14.0           14              12.5       17.5
# 9    0.52642820  11.5           11              10.0       12.5
# 10   0.98218415   8.0            8               8.0       12.5
# 11   0.98762769  10.0           10               9.0       12.5
# 12   0.42679449  15.0           15              12.5        9.5
# 13   0.11165664  17.0           17              16.0        6.0
# 14   0.30992887  11.5           12              17.0       15.0
# 15   0.60321075   9.0            9              11.0        9.5
# 16   0.61889111  16.0           16              15.0       19.0
# 17   0.14921191  19.0           19              19.0       17.5
# 18   0.77402307  18.0           18              18.0       12.5
# 19   0.39738508  13.0           13              14.0       16.0
# 20   0.57862741  20.0           20              20.0       20.0
# 21   0.09569006   2.0            2               2.0        3.0
# 22   0.31060514   1.0            1               1.0        1.5
# 23   0.38487833   3.0            3               3.0        1.5
# 24   0.84655156   4.0            4               4.0        4.0
# 25   0.65432937   6.0            6               6.0       13.0
# 26   0.54516523   7.5            8               8.0        7.5
# 27   0.69518396  15.0           15              10.0       19.0
# 28   0.30997392   5.0            5               5.0        7.5
# 29   0.15105439   9.5            9              11.0       17.0
# 30   0.68014652   7.5            7               7.0        7.5
# ⋮    ⋮           ⋮              ⋮               ⋮          ⋮
# 1971 0.49889255  10.5           11               9.5       17.5
# 1972 0.58140575  20.0           20              20.0       19.5
# 1973 0.31856235  12.0           12              11.0        3.0
# 1974 0.59589171   8.0            9              12.0       11.0
# 1975 0.69750779  17.0           17              15.5       19.5
# 1976 0.92525397   4.0            4               6.0        2.0
# 1977 0.95560469  13.0           13              13.0        9.0
# 1978 0.15632243  16.0           16              19.0       12.0
# 1979 0.18312533  19.0           19              18.0       13.5
# 1980 0.29513197  14.0           14              17.0       16.0
# 1981 0.75433920   1.0            1               2.0        3.0
# 1982 0.76006686   2.0            2               1.0        1.0
# 1983 0.41609165   4.0            4               4.0        7.0
# 1984 0.60966731   3.0            3               3.0        2.0
# 1985 0.89155996   8.5            8               8.0        9.5
# 1986 0.55749439  12.0           12              11.0       17.0
# 1987 0.30892064  13.5           13              12.0       20.0
# 1988 0.62255739   5.0            5               5.0        4.0
# 1989 0.66173745   6.0            6               7.0        6.0
# 1990 0.00250210  10.0           10               9.0       14.0
# 1991 0.66789573  11.0           11              10.0       18.0
# 1992 0.46209011  13.5           14              15.0        8.0
# 1993 0.11686056  17.0           17              16.5       15.5
# 1994 0.54952732  15.0           15              14.0       19.0
# 1995 0.51052792   8.5            9              13.0        9.5
# 1996 0.65235946   7.0            7               6.0       11.0
# 1997 0.91666792  19.0           19              16.5       12.5
# 1998 0.08325074  16.0           16              18.0        5.0
# 1999 0.16116976  20.0           20              19.0       15.5
# 2000 0.44695363  18.0           18              20.0       12.5
#      team_rank prize sim
# 1     2        210   1
# 2     1        225   1
# 3     3        200   1
# 4     5        160   1
# 5     4        190   1
# 6     6        150   1
# 7     7        140   1
# 8    14        110   1
# 9    11        118   1
# 10    8        125   1
# 11   10        120   1
# 12   15        108   1
# 13   17        100   1
# 14   12        115   1
# 15    9        123   1
# 16   16        105   1
# 17   19         50   1
# 18   18         52   1
# 19   13        112   1
# 20   20         49   1
# 21    2        210   2
# 22    1        225   2
# 23    3        200   2
# 24    4        190   2
# 25    6        150   2
# 26    8        125   2
# 27   15        108   2
# 28    5        160   2
# 29    9        123   2
# 30    7        140   2
# ⋮    ⋮         ⋮     ⋮
# 1971 11        118    99
# 1972 20         49    99
# 1973 12        115    99
# 1974  9        123    99
# 1975 17        100    99
# 1976  4        190    99
# 1977 13        112    99
# 1978 16        105    99
# 1979 19         50    99
# 1980 14        110    99
# 1981  1        225   100
# 1982  2        210   100
# 1983  4        190   100
# 1984  3        200   100
# 1985  8        125   100
# 1986 12        115   100
# 1987 13        112   100
# 1988  5        160   100
# 1989  6        150   100
# 1990 10        120   100
# 1991 11        118   100
# 1992 14        110   100
# 1993 17        100   100
# 1994 15        108   100
# 1995  9        123   100
# 1996  7        140   100
# 1997 19         50   100
# 1998 16        105   100
# 1999 20         49   100
# 2000 18         52   100

# %%
Added ten percent to second
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:7: unexpected symbol
# 1: Added ten
#           ^
# Traceback:

# %%
df.prem.matrix.added2<- as.matrix(df.prem)
for (i in 2) {
    df.prem.matrix.added2[i,1]= df.prem.matrix.added2[i,1]*1.10
    print(df.prem.matrix.added2[i,1])
    }
df.prem.matrix.added2
# simulate score line for a match
draw.score<-function(team1,team2){
    c(
        rpois(1,exp(alphaList[team1]-deltaList[team2])),
  rpois(1,exp(alphaList[team2]-deltaList[team1]))
    )
}
draw.score("Liverpool","Arsenal")
# All possible matches in a season
allMatches<-permutations(20, 2, v=rownames(df.prem.matrix.added),repeats.allowed=FALSE)
colnames(allMatches)<-c("home","away")
allMatches
nrow(allMatches)

SeasonSim <- function(allMatches){
     ScoresMatrix <- matrix(nrow=nrow(allMatches),  ncol=4)
        for (ii in 1:nrow(allMatches)  ) {
         ScoresMatrix[ii,1:2]=allMatches[ii,]
         ScoresMatrix[ii,3:4]= as.numeric(draw.score(allMatches[ii,"home"],allMatches[ii,"away"] ))
        }
        colnames(ScoresMatrix)<-c("home.team","away.team","home.score","away.score")
        ScoresMatrix <- as.data.frame(ScoresMatrix)
        ScoresMatrix$home.score <- as.numeric(ScoresMatrix$home.score)
        ScoresMatrix$away.score <- as.numeric(ScoresMatrix$away.score)  
        
        # PEPARING AGGREGATE STATS DFs
        df.points <- as.data.frame(ScoresMatrix)
        df.points_goalsfor <- as.data.frame(ScoresMatrix)
        df.points_goalsagainst <- as.data.frame(ScoresMatrix)
        name <- rownames(df.prem.matrix.added1)
        for (i in 1:20){
            df.points[, name[i]] <- 0
        }
        df.points

        # ASSIGNING POINTS PER MATCH
        for (i in 1:380){ 
            for (j in 1:20){
                if (df.points[i,1] == name[j]){
                    if (df.points[i,3] > df.points[i,4]){
                        df.points[i,j+4] = 3
                    } else if (df.points[i,3] == df.points[i,4]){
                        df.points[i,j+4] = 1
                    } else if (df.points[i,3] < df.points[i,4]){
                        df.points[i,j+4] = 0
                    } 
                } 
                if (df.points[i,2] == name[j]){
                    if (df.points[i,3] > df.points[i,4]){
                        df.points[i,j+4] = 0
                    } else if (df.points[i,3] == df.points[i,4]){
                        df.points[i,j+4] = 1
                    } else if (df.points[i,3] < df.points[i,4]){
                        df.points[i,j+4] = 3
                    }      
                }
            }   
        } 
    
        # PREPARING DFs
        for (i in 1:20){
            df.points_goalsfor[, name[i]] <- 0
        }
        for (i in 1:20){
            df.points_goalsagainst[, name[i]] <- 0
        }
    
        # GOALS FOR
        for (i in 1:380){
            for (j in 1:20){
                if (df.points_goalsfor[i,1] == name[j]){ # looking at home team
                    df.points_goalsfor[i,j+4] = df.points_goalsfor[i,3]  # home points go to goals for
                }
                if (df.points_goalsfor[i,2] == name[j]){ # looking at away team
                    df.points_goalsfor[i,j+4] = df.points_goalsfor[i,4] # away points go to goals for
                }
            }
        }
    
        # GOALS AGAINST
        for (i in 1:380){
            for (j in 1:20){
                if (df.points_goalsagainst[i,1] == name[j]){ # looking at home team
                    df.points_goalsagainst[i,j+4] = df.points_goalsagainst[i,4]  # home points go to goals for
                }
                if (df.points_goalsagainst[i,2] == name[j]){ # looking at away team
                    df.points_goalsagainst[i,j+4] = df.points_goalsagainst[i,3] # away points go to goals for
                }
            }
        } 
        
        # AGGREGATING POINTS and GOALS
        points <- df.points[,c(-1,-2,-3,-4)]
        points <- sapply(points, as.numeric)
        points_sum <- as.data.frame(colSums(points))
        
        goalsfor <- df.points_goalsfor[,c(-1,-2,-3,-4)]
        goalsfor <- sapply(goalsfor, as.numeric)
        goalsfor_sum <- as.data.frame(colSums(goalsfor))
    
        goalsagainst <- df.points_goalsagainst[,c(-1,-2,-3,-4)]
        goalsagainst <- sapply(goalsagainst, as.numeric)
        goalsagainst_sum <- as.data.frame(colSums(goalsagainst))

        # MERGE TO ONE DF
        df.teams <- cbind(points_sum, goalsfor_sum, goalsagainst_sum)
        colnames(df.teams)[1] <- 'points'
        colnames(df.teams)[2] <- 'goals_for'
        colnames(df.teams)[3] <- 'goals_against'
        df.teams$team_names <- row.names(df.teams)
    
        # ADD TIE BREAKER VARIABLES
        df.teams <- df.teams %>%
            mutate(net_goals = goals_for - goals_against) %>%
            mutate(tie_breaker = runif(20, 0, 1))
        df.teams1 <- df.teams
        df.teams1$temp_team_rank <- rank(desc(df.teams1$points))
        df.teams1$temp_team_rank2 <- rank(desc(df.teams1$points))
        df.teams1$goals_rank <- rank(desc(df.teams1$net_goals))
        df.teams1$goalsfor_rank <- rank(desc(df.teams1$goals_for))
        df.teams1
    
        # RANK 
        for (ii in 1:nrow(df.teams1)){
            for (jj in 1:nrow(df.teams1)){
                if (ii != jj & df.teams1[ii,7] == df.teams1[jj,7]){
                    if (df.teams1[ii,9] > df.teams1[jj,9]){ #goals rank
                        df.teams1[ii,8] = df.teams1[ii,8]+0.5
                        df.teams1[jj,8] = df.teams1[jj,8]-0.5
                    } else if (df.teams1[ii,9] == df.teams1[jj,9]){ 
                        if (df.teams1[ii,10] > df.teams1[jj,10]){ #goals_for rank
                            df.teams1[ii,8] = df.teams1[ii,8]+0.5
                            df.teams1[jj,8] = df.teams1[jj,8]-0.5
                        } else if (df.teams1[ii,10] == df.teams1[jj,10]){                   
                            if (df.teams1[ii,6] > df.teams1[jj,6]){
                            df.teams1[ii,8] = df.teams1[ii,8]+0.5
                            df.teams1[jj,8] = df.teams1[jj,8]-0.5
                            }   
                        }
                    }
                }
            }
        }
        df.teams1$team_rank <- rank(df.teams1$temp_team_rank2)
        
         # ASSIGN PRIZE
        df.earnings <- left_join(df.teams1, prizes, by=c("team_rank"))
        df.earnings
    }

SeasonSim(allMatches)

# results df
finalcol <- c("points", "goals_for", "goals_against", "team_names", "net_goals", "tie_breaker", "team_rank", "goals_rank", "goalsfor_rank", "prize")
df.final.output1 <- as.data.frame(matrix(ncol = length(finalcol), nrow=0, dimnames = list(NULL,finalcol)))

# simulations
nsims <- 100

# simulation
for (rep in 1:nsims) {
    df.sim.earnings <- SeasonSim(allMatches)
    df.sim.earnings$sim <- rep
    df.final.output1 <- rbind(df.final.output1, df.sim.earnings)
}
df.final.output1
# Out:
# [1] 2.9
#                          off  def  alpha     delta
# Manchester City          2.90 0.20 1.3835395 2.3108012
# Liverpool                2.92 0.25 1.3904124 2.0876577
# Chelsea                  2.39 0.29 1.1901222 1.9392377
# Arsenal                  2.16 0.46 1.0889370 1.4778921
# Tottenham Hotspur        2.36 0.65 1.1774904 1.1321463
# Manchester United        2.19 0.67 1.1027303 1.1018409
# Aston Villa              1.99 0.63 1.0069634 1.1633988
# West Ham United          2.02 0.73 1.0219263 1.0160741
# Brighton and Hove Albion 1.85 0.62 0.9340144 1.1793991
# Crystal Palace           1.89 0.69 0.9554056 1.0724270
# Wolverhampton            1.73 0.61 0.8669502 1.1956597
# Southampton              1.94 0.89 0.9815168 0.8178972
# Leicester City           2.04 1.00 1.0317786 0.7013633
# Brentford                1.80 0.85 0.9066155 0.8638823
# Newcastle                1.75 0.82 0.8784446 0.8998143
# Burnley                  1.62 0.83 0.8012550 0.8876929
# Everton                  1.70 0.93 0.8494571 0.7739340
# Leeds United             1.92 1.15 0.9711540 0.5616014
# Watford                  1.65 1.08 0.8196041 0.6244023
# Norwich City             1.51 1.19 0.7309385 0.5274100
# [1] 0 0
#       home            away
#  [1,] Arsenal         Aston Villa
#  [2,] Arsenal         Brentford
#  [3,] Arsenal         Brighton and Hove Albion
#  [4,] Arsenal         Burnley
#  [5,] Arsenal         Chelsea
#  [6,] Arsenal         Crystal Palace
#  [7,] Arsenal         Everton
#  [8,] Arsenal         Leeds United
#  [9,] Arsenal         Leicester City
# [10,] Arsenal         Liverpool
# [11,] Arsenal         Manchester City
# [12,] Arsenal         Manchester United
# [13,] Arsenal         Newcastle
# [14,] Arsenal         Norwich City
# [15,] Arsenal         Southampton
# [16,] Arsenal         Tottenham Hotspur
# [17,] Arsenal         Watford
# [18,] Arsenal         West Ham United
# [19,] Arsenal         Wolverhampton
# [20,] Aston Villa     Arsenal
# [21,] Aston Villa     Brentford
# [22,] Aston Villa     Brighton and Hove Albion
# [23,] Aston Villa     Burnley
# [24,] Aston Villa     Chelsea
# [25,] Aston Villa     Crystal Palace
# [26,] Aston Villa     Everton
# [27,] Aston Villa     Leeds United
# [28,] Aston Villa     Leicester City
# [29,] Aston Villa     Liverpool
# [30,] Aston Villa     Manchester City
# [31,] ⋮               ⋮
# [32,] West Ham United Leeds United
# [33,] West Ham United Leicester City
# [34,] West Ham United Liverpool
# [35,] West Ham United Manchester City
# [36,] West Ham United Manchester United
# [37,] West Ham United Newcastle
# [38,] West Ham United Norwich City
# [39,] West Ham United Southampton
# [40,] West Ham United Tottenham Hotspur
# [41,] West Ham United Watford
# [42,] West Ham United Wolverhampton
# [43,] Wolverhampton   Arsenal
# [44,] Wolverhampton   Aston Villa
# [45,] Wolverhampton   Brentford
# [46,] Wolverhampton   Brighton and Hove Albion
# [47,] Wolverhampton   Burnley
# [48,] Wolverhampton   Chelsea
# [49,] Wolverhampton   Crystal Palace
# [50,] Wolverhampton   Everton
# [51,] Wolverhampton   Leeds United
# [52,] Wolverhampton   Leicester City
# [53,] Wolverhampton   Liverpool
# [54,] Wolverhampton   Manchester City
# [55,] Wolverhampton   Manchester United
# [56,] Wolverhampton   Newcastle
# [57,] Wolverhampton   Norwich City
# [58,] Wolverhampton   Southampton
# [59,] Wolverhampton   Tottenham Hotspur
# [60,] Wolverhampton   Watford
# [61,] Wolverhampton   West Ham United
# [1] 380
#    points goals_for goals_against team_names               net_goals
# 1  85     48         7            Manchester City           41
# 2  88     48         8            Liverpool                 40
# 3  70     51        23            Chelsea                   28
# 4  63     41        23            Arsenal                   18
# 5  57     55        41            Tottenham Hotspur         14
# 6  49     34        41            Manchester United         -7
# 7  67     49        26            Aston Villa               23
# 8  53     35        38            West Ham United           -3
# 9  51     38        39            Brighton and Hove Albion  -1
# 10 58     40        28            Crystal Palace            12
# 11 51     29        30            Wolverhampton             -1
# 12 47     38        44            Southampton               -6
# 13 41     40        47            Leicester City            -7
# 14 50     37        40            Brentford                 -3
# 15 42     37        47            Newcastle                -10
# 16 38     34        62            Burnley                  -28
# 17 36     35        60            Everton                  -25
# 18 22     16        53            Leeds United             -37
# 19 30     34        50            Watford                  -16
# 20 32     28        60            Norwich City             -32
#    tie_breaker temp_team_rank temp_team_rank2 goals_rank goalsfor_rank
# 1  0.54470026   2.0            2               1.0        4.5
# 2  0.45326386   1.0            1               2.0        4.5
# 3  0.89880641   3.0            3               3.0        2.0
# 4  0.71619113   5.0            5               5.0        6.0
# 5  0.32456524   7.0            7               6.0        1.0
# 6  0.02465531  12.0           12              13.5       16.0
# 7  0.92495789   4.0            4               4.0        3.0
# 8  0.19052632   8.0            8              10.5       13.5
# 9  0.56349693   9.5            9               8.5        9.5
# 10 0.44546075   6.0            6               7.0        7.5
# 11 0.08161977   9.5           10               8.5       18.0
# 12 0.57616133  13.0           13              12.0        9.5
# 13 0.35313942  15.0           15              13.5        7.5
# 14 0.34261240  11.0           11              10.5       11.5
# 15 0.45372822  14.0           14              15.0       11.5
# 16 0.84647445  16.0           16              18.0       16.0
# 17 0.21538255  17.0           17              17.0       13.5
# 18 0.46428596  20.0           20              20.0       20.0
# 19 0.91935298  19.0           19              16.0       16.0
# 20 0.29161198  18.0           18              19.0       19.0
#    team_rank prize
# 1   2        210
# 2   1        225
# 3   3        200
# 4   5        160
# 5   7        140
# 6  12        115
# 7   4        190
# 8   8        125
# 9   9        123
# 10  6        150
# 11 10        120
# 12 13        112
# 13 15        108
# 14 11        118
# 15 14        110
# 16 16        105
# 17 17        100
# 18 20         49
# 19 19         50
# 20 18         52

# %%
Added ten percent to second

# %%
df.prem.matrix.added2<- as.matrix(df.prem)
for (i in 2) {
    df.prem.matrix.added2[i,1]= df.prem.matrix.added2[i,1]*1.10
    print(df.prem.matrix.added2[i,1])
    }
df.prem.matrix.added2
# simulate score line for a match
draw.score<-function(team1,team2){
    c(
        rpois(1,exp(alphaList[team1]-deltaList[team2])),
  rpois(1,exp(alphaList[team2]-deltaList[team1]))
    )
}
draw.score("Liverpool","Arsenal")
# All possible matches in a season
allMatches<-permutations(20, 2, v=rownames(df.prem.matrix.added),repeats.allowed=FALSE)
colnames(allMatches)<-c("home","away")
allMatches
nrow(allMatches)

SeasonSim <- function(allMatches){
     ScoresMatrix <- matrix(nrow=nrow(allMatches),  ncol=4)
        for (ii in 1:nrow(allMatches)  ) {
         ScoresMatrix[ii,1:2]=allMatches[ii,]
         ScoresMatrix[ii,3:4]= as.numeric(draw.score(allMatches[ii,"home"],allMatches[ii,"away"] ))
        }
        colnames(ScoresMatrix)<-c("home.team","away.team","home.score","away.score")
        ScoresMatrix <- as.data.frame(ScoresMatrix)
        ScoresMatrix$home.score <- as.numeric(ScoresMatrix$home.score)
        ScoresMatrix$away.score <- as.numeric(ScoresMatrix$away.score)  
        
        # PEPARING AGGREGATE STATS DFs
        df.points <- as.data.frame(ScoresMatrix)
        df.points_goalsfor <- as.data.frame(ScoresMatrix)
        df.points_goalsagainst <- as.data.frame(ScoresMatrix)
        name <- rownames(df.prem.matrix.added1)
        for (i in 1:20){
            df.points[, name[i]] <- 0
        }
        df.points

        # ASSIGNING POINTS PER MATCH
        for (i in 1:380){ 
            for (j in 1:20){
                if (df.points[i,1] == name[j]){
                    if (df.points[i,3] > df.points[i,4]){
                        df.points[i,j+4] = 3
                    } else if (df.points[i,3] == df.points[i,4]){
                        df.points[i,j+4] = 1
                    } else if (df.points[i,3] < df.points[i,4]){
                        df.points[i,j+4] = 0
                    } 
                } 
                if (df.points[i,2] == name[j]){
                    if (df.points[i,3] > df.points[i,4]){
                        df.points[i,j+4] = 0
                    } else if (df.points[i,3] == df.points[i,4]){
                        df.points[i,j+4] = 1
                    } else if (df.points[i,3] < df.points[i,4]){
                        df.points[i,j+4] = 3
                    }      
                }
            }   
        } 
    
        # PREPARING DFs
        for (i in 1:20){
            df.points_goalsfor[, name[i]] <- 0
        }
        for (i in 1:20){
            df.points_goalsagainst[, name[i]] <- 0
        }
    
        # GOALS FOR
        for (i in 1:380){
            for (j in 1:20){
                if (df.points_goalsfor[i,1] == name[j]){ # looking at home team
                    df.points_goalsfor[i,j+4] = df.points_goalsfor[i,3]  # home points go to goals for
                }
                if (df.points_goalsfor[i,2] == name[j]){ # looking at away team
                    df.points_goalsfor[i,j+4] = df.points_goalsfor[i,4] # away points go to goals for
                }
            }
        }
    
        # GOALS AGAINST
        for (i in 1:380){
            for (j in 1:20){
                if (df.points_goalsagainst[i,1] == name[j]){ # looking at home team
                    df.points_goalsagainst[i,j+4] = df.points_goalsagainst[i,4]  # home points go to goals for
                }
                if (df.points_goalsagainst[i,2] == name[j]){ # looking at away team
                    df.points_goalsagainst[i,j+4] = df.points_goalsagainst[i,3] # away points go to goals for
                }
            }
        } 
        
        # AGGREGATING POINTS and GOALS
        points <- df.points[,c(-1,-2,-3,-4)]
        points <- sapply(points, as.numeric)
        points_sum <- as.data.frame(colSums(points))
        
        goalsfor <- df.points_goalsfor[,c(-1,-2,-3,-4)]
        goalsfor <- sapply(goalsfor, as.numeric)
        goalsfor_sum <- as.data.frame(colSums(goalsfor))
    
        goalsagainst <- df.points_goalsagainst[,c(-1,-2,-3,-4)]
        goalsagainst <- sapply(goalsagainst, as.numeric)
        goalsagainst_sum <- as.data.frame(colSums(goalsagainst))

        # MERGE TO ONE DF
        df.teams <- cbind(points_sum, goalsfor_sum, goalsagainst_sum)
        colnames(df.teams)[1] <- 'points'
        colnames(df.teams)[2] <- 'goals_for'
        colnames(df.teams)[3] <- 'goals_against'
        df.teams$team_names <- row.names(df.teams)
    
        # ADD TIE BREAKER VARIABLES
        df.teams <- df.teams %>%
            mutate(net_goals = goals_for - goals_against) %>%
            mutate(tie_breaker = runif(20, 0, 1))
        df.teams1 <- df.teams
        df.teams1$temp_team_rank <- rank(desc(df.teams1$points))
        df.teams1$temp_team_rank2 <- rank(desc(df.teams1$points))
        df.teams1$goals_rank <- rank(desc(df.teams1$net_goals))
        df.teams1$goalsfor_rank <- rank(desc(df.teams1$goals_for))
        df.teams1
    
        # RANK 
        for (ii in 1:nrow(df.teams1)){
            for (jj in 1:nrow(df.teams1)){
                if (ii != jj & df.teams1[ii,7] == df.teams1[jj,7]){
                    if (df.teams1[ii,9] > df.teams1[jj,9]){ #goals rank
                        df.teams1[ii,8] = df.teams1[ii,8]+0.5
                        df.teams1[jj,8] = df.teams1[jj,8]-0.5
                    } else if (df.teams1[ii,9] == df.teams1[jj,9]){ 
                        if (df.teams1[ii,10] > df.teams1[jj,10]){ #goals_for rank
                            df.teams1[ii,8] = df.teams1[ii,8]+0.5
                            df.teams1[jj,8] = df.teams1[jj,8]-0.5
                        } else if (df.teams1[ii,10] == df.teams1[jj,10]){                   
                            if (df.teams1[ii,6] > df.teams1[jj,6]){
                            df.teams1[ii,8] = df.teams1[ii,8]+0.5
                            df.teams1[jj,8] = df.teams1[jj,8]-0.5
                            }   
                        }
                    }
                }
            }
        }
        df.teams1$team_rank <- rank(df.teams1$temp_team_rank2)
        
         # ASSIGN PRIZE
        df.earnings <- left_join(df.teams1, prizes, by=c("team_rank"))
        df.earnings
    }

SeasonSim(allMatches)

# results df
finalcol <- c("points", "goals_for", "goals_against", "team_names", "net_goals", "tie_breaker", "team_rank", "goals_rank", "goalsfor_rank", "prize")
df.final.output <- as.data.frame(matrix(ncol = length(finalcol), nrow=0, dimnames = list(NULL,finalcol)))

# simulations
nsims <- 100

# simulation
for (rep in 1:nsims) {
    df.sim.earnings <- SeasonSim(allMatches)
    df.sim.earnings$sim <- rep
    df.final.output <- rbind(df.final.output, df.sim.earnings)
}
df.final.output1
# Out:
# [1] 2.9
#                          off  def  alpha     delta
# Manchester City          2.90 0.20 1.3835395 2.3108012
# Liverpool                2.92 0.25 1.3904124 2.0876577
# Chelsea                  2.39 0.29 1.1901222 1.9392377
# Arsenal                  2.16 0.46 1.0889370 1.4778921
# Tottenham Hotspur        2.36 0.65 1.1774904 1.1321463
# Manchester United        2.19 0.67 1.1027303 1.1018409
# Aston Villa              1.99 0.63 1.0069634 1.1633988
# West Ham United          2.02 0.73 1.0219263 1.0160741
# Brighton and Hove Albion 1.85 0.62 0.9340144 1.1793991
# Crystal Palace           1.89 0.69 0.9554056 1.0724270
# Wolverhampton            1.73 0.61 0.8669502 1.1956597
# Southampton              1.94 0.89 0.9815168 0.8178972
# Leicester City           2.04 1.00 1.0317786 0.7013633
# Brentford                1.80 0.85 0.9066155 0.8638823
# Newcastle                1.75 0.82 0.8784446 0.8998143
# Burnley                  1.62 0.83 0.8012550 0.8876929
# Everton                  1.70 0.93 0.8494571 0.7739340
# Leeds United             1.92 1.15 0.9711540 0.5616014
# Watford                  1.65 1.08 0.8196041 0.6244023
# Norwich City             1.51 1.19 0.7309385 0.5274100
# [1] 0 0
#       home            away
#  [1,] Arsenal         Aston Villa
#  [2,] Arsenal         Brentford
#  [3,] Arsenal         Brighton and Hove Albion
#  [4,] Arsenal         Burnley
#  [5,] Arsenal         Chelsea
#  [6,] Arsenal         Crystal Palace
#  [7,] Arsenal         Everton
#  [8,] Arsenal         Leeds United
#  [9,] Arsenal         Leicester City
# [10,] Arsenal         Liverpool
# [11,] Arsenal         Manchester City
# [12,] Arsenal         Manchester United
# [13,] Arsenal         Newcastle
# [14,] Arsenal         Norwich City
# [15,] Arsenal         Southampton
# [16,] Arsenal         Tottenham Hotspur
# [17,] Arsenal         Watford
# [18,] Arsenal         West Ham United
# [19,] Arsenal         Wolverhampton
# [20,] Aston Villa     Arsenal
# [21,] Aston Villa     Brentford
# [22,] Aston Villa     Brighton and Hove Albion
# [23,] Aston Villa     Burnley
# [24,] Aston Villa     Chelsea
# [25,] Aston Villa     Crystal Palace
# [26,] Aston Villa     Everton
# [27,] Aston Villa     Leeds United
# [28,] Aston Villa     Leicester City
# [29,] Aston Villa     Liverpool
# [30,] Aston Villa     Manchester City
# [31,] ⋮               ⋮
# [32,] West Ham United Leeds United
# [33,] West Ham United Leicester City
# [34,] West Ham United Liverpool
# [35,] West Ham United Manchester City
# [36,] West Ham United Manchester United
# [37,] West Ham United Newcastle
# [38,] West Ham United Norwich City
# [39,] West Ham United Southampton
# [40,] West Ham United Tottenham Hotspur
# [41,] West Ham United Watford
# [42,] West Ham United Wolverhampton
# [43,] Wolverhampton   Arsenal
# [44,] Wolverhampton   Aston Villa
# [45,] Wolverhampton   Brentford
# [46,] Wolverhampton   Brighton and Hove Albion
# [47,] Wolverhampton   Burnley
# [48,] Wolverhampton   Chelsea
# [49,] Wolverhampton   Crystal Palace
# [50,] Wolverhampton   Everton
# [51,] Wolverhampton   Leeds United
# [52,] Wolverhampton   Leicester City
# [53,] Wolverhampton   Liverpool
# [54,] Wolverhampton   Manchester City
# [55,] Wolverhampton   Manchester United
# [56,] Wolverhampton   Newcastle
# [57,] Wolverhampton   Norwich City
# [58,] Wolverhampton   Southampton
# [59,] Wolverhampton   Tottenham Hotspur
# [60,] Wolverhampton   Watford
# [61,] Wolverhampton   West Ham United
# [1] 380
#    points goals_for goals_against team_names               net_goals
# 1  78     58         7            Manchester City           51
# 2  89     53         7            Liverpool                 46
# 3  72     42        11            Chelsea                   31
# 4  64     43        23            Arsenal                   20
# 5  59     47        34            Tottenham Hotspur         13
# 6  55     37        26            Manchester United         11
# 7  54     43        43            Aston Villa                0
# 8  49     42        51            West Ham United           -9
# 9  54     30        30            Brighton and Hove Albion   0
# 10 48     29        34            Crystal Palace            -5
# 11 53     44        39            Wolverhampton              5
# 12 51     37        36            Southampton                1
# 13 36     33        57            Leicester City           -24
# 14 38     41        47            Brentford                 -6
# 15 36     28        47            Newcastle                -19
# 16 49     35        43            Burnley                   -8
# 17 43     32        43            Everton                  -11
# 18 28     27        66            Leeds United             -39
# 19 39     42        59            Watford                  -17
# 20 33     31        71            Norwich City             -40
#    tie_breaker temp_team_rank temp_team_rank2 goals_rank goalsfor_rank
# 1  0.896061902  2.0            2               1.0        1.0
# 2  0.560939923  1.0            1               2.0        2.0
# 3  0.979776159  3.0            3               3.0        8.0
# 4  0.889902761  4.0            4               4.0        5.5
# 5  0.745098545  5.0            5               5.0        3.0
# 6  0.221165151  6.0            6               6.0       11.5
# 7  0.246114778  7.5            7               9.5        5.5
# 8  0.296668438 11.5           12              14.0        8.0
# 9  0.120422996  7.5            8               9.5       17.0
# 10 0.006833071 13.0           13              11.0       18.0
# 11 0.569888525  9.0            9               7.0        4.0
# 12 0.419364768 10.0           10               8.0       11.5
# 13 0.738009210 17.5           18              18.0       14.0
# 14 0.269888121 16.0           16              12.0       10.0
# 15 0.607537386 17.5           17              17.0       19.0
# 16 0.311069053 11.5           11              13.0       13.0
# 17 0.722946014 14.0           14              15.0       15.0
# 18 0.730553839 20.0           20              19.0       20.0
# 19 0.344145467 15.0           15              16.0        8.0
# 20 0.097911074 19.0           19              20.0       16.0
#    team_rank prize
# 1   2        210
# 2   1        225
# 3   3        200
# 4   4        190
# 5   5        160
# 6   6        150
# 7   7        140
# 8  12        115
# 9   8        125
# 10 13        112
# 11  9        123
# 12 10        120
# 13 18         52
# 14 16        105
# 15 17        100
# 16 11        118
# 17 14        110
# 18 20         49
# 19 15        108
# 20 19         50

# %%
# results df
finalcol <- c("points", "goals_for", "goals_against", "team_names", "net_goals", "tie_breaker", "team_rank", "goals_rank", "goalsfor_rank", "prize")
df.final.output <- as.data.frame(matrix(ncol = length(finalcol), nrow=0, dimnames = list(NULL,finalcol)))

# simulations
nsims <- 100

# simulation
for (rep in 1:nsims) {
    df.sim.earnings <- SeasonSim(allMatches)
    df.sim.earnings$sim <- rep
    df.final.output <- rbind(df.final.output, df.sim.earnings)
}
df.final.output
# Out:
#      points goals_for goals_against team_names               net_goals
# 1    89     68         7            Manchester City           61
# 2    87     60        11            Liverpool                 49
# 3    66     35        21            Chelsea                   14
# 4    52     27        26            Arsenal                    1
# 5    70     50        36            Tottenham Hotspur         14
# 6    59     53        38            Manchester United         15
# 7    59     40        31            Aston Villa                9
# 8    39     31        45            West Ham United          -14
# 9    46     32        43            Brighton and Hove Albion -11
# 10   51     39        36            Crystal Palace             3
# 11   59     35        29            Wolverhampton              6
# 12   41     33        40            Southampton               -7
# 13   42     34        49            Leicester City           -15
# 14   50     43        42            Brentford                  1
# 15   53     43        39            Newcastle                  4
# 16   36     42        61            Burnley                  -19
# 17   30     26        51            Everton                  -25
# 18   40     38        57            Leeds United             -19
# 19   31     24        61            Watford                  -37
# 20   29     33        63            Norwich City             -30
# 21   94     61        10            Manchester City           51
# 22   79     50         9            Liverpool                 41
# 23   82     53        13            Chelsea                   40
# 24   50     33        30            Arsenal                    3
# 25   40     39        44            Tottenham Hotspur         -5
# 26   56     43        37            Manchester United          6
# 27   69     44        26            Aston Villa               18
# 28   52     43        42            West Ham United            1
# 29   59     39        27            Brighton and Hove Albion  12
# 30   46     34        37            Crystal Palace            -3
# ⋮    ⋮      ⋮         ⋮             ⋮                        ⋮
# 1971 58     31        23            Wolverhampton              8
# 1972 44     39        50            Southampton              -11
# 1973 42     32        49            Leicester City           -17
# 1974 42     27        43            Brentford                -16
# 1975 51     39        41            Newcastle                 -2
# 1976 43     28        42            Burnley                  -14
# 1977 39     36        48            Everton                  -12
# 1978 37     43        68            Leeds United             -25
# 1979 27     32        60            Watford                  -28
# 1980 27     28        70            Norwich City             -42
# 1981 82     48        10            Manchester City           38
# 1982 81     52        14            Liverpool                 38
# 1983 81     39         6            Chelsea                   33
# 1984 59     38        27            Arsenal                   11
# 1985 62     43        28            Tottenham Hotspur         15
# 1986 45     38        35            Manchester United          3
# 1987 50     39        34            Aston Villa                5
# 1988 59     40        29            West Ham United           11
# 1989 69     43        37            Brighton and Hove Albion   6
# 1990 43     36        36            Crystal Palace             0
# 1991 55     32        34            Wolverhampton             -2
# 1992 38     32        48            Southampton              -16
# 1993 42     36        47            Leicester City           -11
# 1994 36     35        45            Brentford                -10
# 1995 36     32        50            Newcastle                -18
# 1996 44     32        36            Burnley                   -4
# 1997 38     30        42            Everton                  -12
# 1998 36     33        61            Leeds United             -28
# 1999 35     38        64            Watford                  -26
# 2000 25     33        66            Norwich City             -33
#      tie_breaker  temp_team_rank temp_team_rank2 goals_rank goalsfor_rank
# 1    0.77286464    1.0            1               1.0        1.0
# 2    0.14378178    2.0            2               2.0        2.0
# 3    0.33537715    4.0            4               4.5       11.5
# 4    0.37322462    9.0            9              10.5       18.0
# 5    0.52060011    3.0            3               4.5        4.0
# 6    0.22689283    6.0            5               3.0        3.0
# 7    0.29158052    6.0            6               6.0        8.0
# 8    0.91110784   16.0           16              14.0       17.0
# 9    0.92587035   12.0           12              13.0       16.0
# 10   0.45899949   10.0           10               9.0        9.0
# 11   0.64338399    6.0            7               7.0       11.5
# 12   0.21973050   14.0           14              12.0       14.5
# 13   0.71202518   13.0           13              15.0       13.0
# 14   0.58503022   11.0           11              10.5        5.5
# 15   0.14596964    8.0            8               8.0        5.5
# 16   0.73477483   17.0           17              16.5        7.0
# 17   0.73190319   19.0           19              18.0       19.0
# 18   0.55705560   15.0           15              16.5       10.0
# 19   0.16652208   18.0           18              20.0       20.0
# 20   0.09945811   20.0           20              19.0       14.5
# 21   0.10258119    1.0            1               1.0        1.0
# 22   0.09684148    3.0            3               2.0        3.0
# 23   0.23622404    2.0            2               3.0        2.0
# 24   0.79772947    9.0            9               8.0       15.0
# 25   0.20666913   16.0           16              11.0        8.5
# 26   0.68903285    7.0            7               6.5        5.5
# 27   0.59235398    4.0            4               4.0        4.0
# 28   0.44964180    8.0            8               9.0        5.5
# 29   0.35042326    5.0            5               5.0        8.5
# 30   0.56863487   11.5           11              10.0       13.5
# ⋮    ⋮            ⋮              ⋮               ⋮          ⋮
# 1971 0.0138158964  6.0            6               7.0       16.0
# 1972 0.7774073582 12.0           12              13.0        9.5
# 1973 0.2036075636 15.0           16              17.0       14.5
# 1974 0.1526405874 15.0           15              16.0       20.0
# 1975 0.0860705231 10.0           10              10.0        9.5
# 1976 0.2479439694 13.0           13              15.0       18.5
# 1977 0.9407505381 17.0           17              14.0       12.0
# 1978 0.9362245305 18.0           18              18.0        5.0
# 1979 0.2798753448 19.5           19              19.0       14.5
# 1980 0.5386336751 19.5           20              20.0       18.5
# 1981 0.2029425893  1.0            1               1.5        2.0
# 1982 0.4427345020  2.5            2               1.5        1.0
# 1983 0.3911546846  2.5            3               3.0        6.5
# 1984 0.3123891067  6.5            7               5.5        9.0
# 1985 0.0003002796  5.0            5               4.0        3.5
# 1986 0.2553265186 10.0           10               9.0        9.0
# 1987 0.8803716758  9.0            9               8.0        6.5
# 1988 0.2724392249  6.5            6               5.5        5.0
# 1989 0.3129754951  4.0            4               7.0        3.5
# 1990 0.8462679838 12.0           12              10.0       11.5
# 1991 0.2692649511  8.0            8              11.0       17.5
# 1992 0.3664069423 14.5           15              16.0       17.5
# 1993 0.7403667127 13.0           13              14.0       11.5
# 1994 0.7411275974 17.0           16              13.0       13.0
# 1995 0.1680829341 17.0           17              17.0       17.5
# 1996 0.2837012617 11.0           11              12.0       17.5
# 1997 0.8903517732 14.5           14              15.0       20.0
# 1998 0.7900210957 17.0           18              19.0       14.5
# 1999 0.2963687696 19.0           19              18.0        9.0
# 2000 0.8658047933 20.0           20              20.0       14.5
#      team_rank prize sim
# 1     1        225   1
# 2     2        210   1
# 3     4        190   1
# 4     9        123   1
# 5     3        200   1
# 6     5        160   1
# 7     6        150   1
# 8    16        105   1
# 9    12        115   1
# 10   10        120   1
# 11    7        140   1
# 12   14        110   1
# 13   13        112   1
# 14   11        118   1
# 15    8        125   1
# 16   17        100   1
# 17   19         50   1
# 18   15        108   1
# 19   18         52   1
# 20   20         49   1
# 21    1        225   2
# 22    3        200   2
# 23    2        210   2
# 24    9        123   2
# 25   16        105   2
# 26    7        140   2
# 27    4        190   2
# 28    8        125   2
# 29    5        160   2
# 30   11        118   2
# ⋮    ⋮         ⋮     ⋮
# 1971  6        150    99
# 1972 12        115    99
# 1973 16        105    99
# 1974 15        108    99
# 1975 10        120    99
# 1976 13        112    99
# 1977 17        100    99
# 1978 18         52    99
# 1979 19         50    99
# 1980 20         49    99
# 1981  1        225   100
# 1982  2        210   100
# 1983  3        200   100
# 1984  7        140   100
# 1985  5        160   100
# 1986 10        120   100
# 1987  9        123   100
# 1988  6        150   100
# 1989  4        190   100
# 1990 12        115   100
# 1991  8        125   100
# 1992 15        108   100
# 1993 13        112   100
# 1994 16        105   100
# 1995 17        100   100
# 1996 11        118   100
# 1997 14        110   100
# 1998 18         52   100
# 1999 19         50   100
# 2000 20         49   100

# %% [markdown]
# ***ANALYSIS***
# 1. Assemble a ranking of the teams from best to worst according to their expected position in the table.
#     Illustrate this ranking with a clear visualization
# 2. Which teams have the most variability in their simulated earnings?
#     Again, illustrate this variability with a clear visualization.
# 3. Which teams stand to benefit the most in monetary terms from a "lucky win" (converting one of their losses to a win)?
#     Again provide a visualization of this marginal effect
# 4. Finally, for each team, calculate the monetary benefit to each team from either (i) an increase of 10% to their expected goals scored (holding everyone else constant), or (ii) a decreasing in their expected goals conceded by 10% (Note that this means 40 separate simulations!)
#     Use this to provide a clear visualization of the benefits of investing in offense versus defense by team

# %% [markdown]
# ***1. Teams by best to worst expected position***

# %%
head(df.final.output)
# taking averages
df.summary <- df.final.output %>%
    group_by(team_names) %>%
    mutate(avg_rank = mean(team_rank)) %>%
    mutate(avg_prize = mean(prize)) %>%
    mutate(variability = sd(team_rank)) # sqrt of the variance


df.analysis <- select(df.summary, c(4,14,15,16))
df.analysis = unique(df.analysis)
df.analysis
# Out:
#   points goals_for goals_against team_names        net_goals tie_breaker
# 1 88     60         7            Manchester City   53        0.1023045
# 2 91     55         7            Liverpool         48        0.8487599
# 3 72     45        15            Chelsea           30        0.1337073
# 4 68     44        19            Arsenal           25        0.2770542
# 5 54     35        32            Tottenham Hotspur  3        0.2415224
# 6 45     33        34            Manchester United -1        0.8532817
#   temp_team_rank temp_team_rank2 goals_rank goalsfor_rank team_rank prize sim
# 1  2.0           2               1           1.0          2         210   1
# 2  1.0           1               2           2.0          1         225   1
# 3  3.0           3               3           4.0          3         200   1
# 4  4.0           4               4           5.0          4         190   1
# 5  7.5           8               8          11.5          8         125   1
# 6 10.0           9               9          13.0          9         123   1
#    team_names               avg_rank avg_prize variability
# 1  Manchester City           1.57    217.10    0.7142843
# 2  Liverpool                 1.90    212.75    0.9045340
# 3  Chelsea                   2.82    201.45    0.8572920
# 4  Arsenal                   5.02    170.86    1.9642255
# 5  Tottenham Hotspur         6.31    154.19    2.5925106
# 6  Manchester United         7.94    139.28    2.9943381
# 7  Aston Villa               8.25    137.05    3.3131968
# 8  West Ham United           9.77    123.60    3.1522158
# 9  Brighton and Hove Albion  8.91    130.32    2.9579374
# 10 Crystal Palace            9.97    125.25    3.1701098
# 11 Wolverhampton            10.28    123.84    3.4262209
# 12 Southampton              13.37    107.15    3.4367444
# 13 Leicester City           13.91    104.10    3.0154317
# 14 Brentford                13.11    108.53    3.3661866
# 15 Newcastle                13.86    103.12    3.4554013
# 16 Burnley                  14.04    101.40    3.4492570
# 17 Everton                  15.23     96.20    2.9399890
# 18 Leeds United             17.11     76.90    2.5579940
# 19 Watford                  17.70     71.57    2.1579077
# 20 Norwich City             18.93     57.34    1.6712362

# %%
# Visualize rankings/earnings
ggplot(df.analysis, aes(x=reorder(team_names,-avg_prize), y=avg_prize, fill=team_names)) + 
  geom_bar(stat = "identity") +
  theme(axis.text.x = element_text(angle = 45, hjust=1)) +
  xlab('Teams') +
  ylab('Average Earnings') +
  ggtitle('Premier League Teams from Best to Worst') +
  theme(legend.position="none")
# Out:
# plot without title

# %% [markdown]
# ***2. Which teams have the most variability in their simulated earnings?***
# South Hampton, West Ham United, Brentford (based off of sensitive measure of variability)

# %% [markdown]
# Visualizing the range of earnings per team:
# Resistance measure (interquartile range)

# %%
ggplot(df.summary, aes(x=team_names, y=prize, fill=team_names)) +
    geom_boxplot() +
    theme(axis.text.x = element_text(angle = 45, hjust=1)) +
    xlab('Teams') +
    ylab('Earnings (£m)') +
    ggtitle('Premier League Earnings (by range)')
# Out:
# plot without title

# %% [markdown]
# Standard deviation (sensitive measure):
# Use given we won't have extreme outliers since our model doesn't account for shocks

# %%
ggplot(df.analysis, aes(x=team_names, y=variability, fill=team_names)) +
  geom_point(size=2, shape=23) +
    theme(axis.text.x = element_text(angle = 45, hjust=1)) +
    xlab('Teams') +
    ylab('Sq Rt Variance of earnings (£m)') +
    ggtitle('Premier League Earnings Variance')
# Out:
# plot without title

# %% [markdown]
# ***3. Which teams stand to benefit the most in monetary terms from a "lucky win" (converting one of their losses to a win)? (visualization of marginal effect)***

# %%
# clean appropriate variables
df.summary$prize <- as.numeric(df.summary$prize)
df.summary$points <- as.numeric(df.summary$points)
df.summary$goals_for <- as.numeric(df.summary$goals_for)
df.summary$goals_against <- as.numeric(df.summary$goals_against)
df.summary$net_goals <- as.numeric(df.summary$net_goals)
df.summary$tie_breaker <- as.numeric(df.summary$tie_breaker)
df.summary$team.f <- factor(df.summary$team_names)

reg1 <- lm(prize ~ points + team.f + team.f*points, data=df.summary) 
summary(reg1)
# Out:
# Call:
# lm(formula = prize ~ points + team.f + team.f * points, data = df.summary)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -43.918  -6.515   0.266   7.161  40.886
#
# Coefficients:
#                                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)                           -20.081327  12.022959  -1.670 0.095030
# points                                  2.978339   0.186556  15.965  < 2e-16
# team.fAston Villa                       0.036970  14.777730   0.003 0.998004
# team.fBrentford                         7.719672  14.407555   0.536 0.592153
# team.fBrighton and Hove Albion         12.358255  15.894255   0.778 0.436940
# team.fBurnley                           8.365396  13.946820   0.600 0.548704
# team.fChelsea                         133.320001  18.313951   7.280 4.82e-13
# team.fCrystal Palace                   35.279841  15.231192   2.316 0.020645
# team.fEverton                         -11.797012  14.057764  -0.839 0.401470
# team.fLeeds United                    -20.184785  13.626590  -1.481 0.138693
# team.fLeicester City                   11.120548  14.521760   0.766 0.443896
# team.fLiverpool                       123.780244  19.235482   6.435 1.55e-10
# team.fManchester City                 150.906302  20.899572   7.221 7.38e-13
# team.fManchester United               -12.909124  14.995562  -0.861 0.389419
# team.fNewcastle                        -3.048162  14.046338  -0.217 0.828225
# team.fNorwich City                     23.692568  13.072262   1.812 0.070073
# team.fSouthampton                      15.274374  14.029061   1.089 0.276391
# team.fTottenham Hotspur               -32.601878  16.042861  -2.032 0.042271
# team.fWatford                         -15.532130  13.655976  -1.137 0.255516
# team.fWest Ham United                  11.597078  14.927540   0.777 0.437317
# team.fWolverhampton                    36.148689  14.624849   2.472 0.013530
# points:team.fAston Villa               -0.120519   0.242358  -0.497 0.619048
# points:team.fBrentford                 -0.232674   0.257946  -0.902 0.367154
# points:team.fBrighton and Hove Albion  -0.364382   0.270212  -1.349 0.177652
# points:team.fBurnley                   -0.290223   0.249334  -1.164 0.244568
# points:team.fChelsea                   -1.815675   0.260185  -6.978 4.07e-12
# points:team.fCrystal Palace            -0.803838   0.261441  -3.075 0.002137
# points:team.fEverton                    0.261690   0.260384   1.005 0.315015
# points:team.fLeeds United               0.354030   0.258566   1.369 0.171091
# points:team.fLeicester City            -0.321212   0.265719  -1.209 0.226870
# points:team.fLiverpool                 -1.657469   0.260112  -6.372 2.32e-10
# points:team.fManchester City           -1.969039   0.273116  -7.210 7.98e-13
# points:team.fManchester United          0.123956   0.245683   0.505 0.613942
# points:team.fNewcastle                 -0.002161   0.251552  -0.009 0.993147
# points:team.fNorwich City              -1.075089   0.256814  -4.186 2.96e-05
# points:team.fSouthampton               -0.400468   0.248420  -1.612 0.107110
# points:team.fTottenham Hotspur          0.479344   0.256709   1.867 0.062014
# points:team.fWatford                    0.291443   0.269120   1.083 0.278965
# points:team.fWest Ham United           -0.374668   0.254233  -1.474 0.140719
# points:team.fWolverhampton             -0.833183   0.248345  -3.355 0.000809
#
# (Intercept)                           .
# points                                ***
# team.fAston Villa
# team.fBrentford
# team.fBrighton and Hove Albion
# team.fBurnley
# team.fChelsea                         ***
# team.fCrystal Palace                  *
# team.fEverton
# team.fLeeds United
# team.fLeicester City
# team.fLiverpool                       ***
# team.fManchester City                 ***
# team.fManchester United
# team.fNewcastle
# team.fNorwich City                    .
# team.fSouthampton
# team.fTottenham Hotspur               *
# team.fWatford
# team.fWest Ham United
# team.fWolverhampton                   *
# points:team.fAston Villa
# points:team.fBrentford
# points:team.fBrighton and Hove Albion
# points:team.fBurnley
# points:team.fChelsea                  ***
# points:team.fCrystal Palace           **
# points:team.fEverton
# points:team.fLeeds United
# points:team.fLeicester City
# points:team.fLiverpool                ***
# points:team.fManchester City          ***
# points:team.fManchester United
# points:team.fNewcastle
# points:team.fNorwich City             ***
# points:team.fSouthampton
# points:team.fTottenham Hotspur        .
# points:team.fWatford
# points:team.fWest Ham United
# points:team.fWolverhampton            ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 12.28 on 1960 degrees of freedom
# Multiple R-squared:  0.9379,	Adjusted R-squared:  0.9367
# F-statistic: 758.9 on 39 and 1960 DF,  p-value: < 2.2e-16

# %%
points1 <- rep(3, 20)
newdata1 <- data.frame(points1)
names(newdata1)[names(newdata1) == 'points1'] <- 'points'
newdata1$team.f <- df.summary$team.f[1:20]
newdata1$prize <- predict(reg1, newdata1)

points2 <- rep(0, 20)
newdata2 <- data.frame(points2)
names(newdata2)[names(newdata2) == 'points2'] <- 'points'
newdata2$team.f <- df.summary$team.f[1:20]
newdata2$prize <- predict(reg1, newdata2)

newdata1$prize_change <- newdata1$prize - newdata2$prize

newdata1
# Out:
#    points team.f                   prize       prize_change
# 1  3      Manchester City          133.8528778  3.027902
# 2  3      Liverpool                107.6615293  3.962612
# 3  3      Chelsea                  116.7266670  3.487992
# 4  3      Arsenal                  -11.1463090  8.935018
# 5  3      Tottenham Hotspur        -42.3101539 10.373051
# 6  3      Manchester United        -23.6835653  9.306886
# 7  3      Aston Villa              -11.4708973  8.573460
# 8  3      West Ham United           -0.6732341  7.811014
# 9  3      Brighton and Hove Albion   0.1187994  7.841871
# 10 3      Crystal Palace            21.7220164  6.523502
# 11 3      Wolverhampton             22.5028305  6.435468
# 12 3      Southampton                2.9266614  7.733614
# 13 3      Leicester City            -0.9893962  7.971383
# 14 3      Brentford                 -4.1246582  8.236997
# 15 3      Newcastle                -14.2009535  8.928535
# 16 3      Burnley                   -3.6515820  8.064349
# 17 3      Everton                  -22.1582522  9.720086
# 18 3      Leeds United             -30.2690031  9.997108
# 19 3      Watford                  -25.8041106  9.809346
# 20 3      Norwich City               9.3209924  5.709751

# %%
ggplot(newdata1, aes(x=reorder(team.f,-prize_change), y=prize_change, fill=team.f)) + 
  geom_bar(stat = "identity") +
  theme(axis.text.x = element_text(angle = 45, hjust=1)) +
  xlab('Teams') +
  ylab('Prize Change') +
  ggtitle('The Marginal Effect of a "Lucky Win"') +
  theme(legend.position="none")
# Out:
# plot without title

# %%
# plot (not right code, just a template)
ggplot(dummy, aes(x=x, y=predicted)) +
  geom_bar(stat = "identity", position = position_dodge()) +
  geom_errorbar(aes(ymin = conf.low, ymax = conf.high), alpha = .9,position = position_dodge())+
  labs(
    x="Sex",
    y="Salary",
    title="The Marginal Effect of Sex on Salary"
  )+scale_x_continuous(breaks=c(1,2) ,labels = c("Female", "Male"))

# %% [markdown]
# ***4. Finally, for each team, calculate the monetary benefit to each team from either
#     (i) an increase of 10% to their expected goals scored (holding everyone else constant), or
#     (ii) a decreasing in their expected goals conceded by 10% (Note that this means 40 separate simulations!)***
#
#     Use this to provide a clear visualization of the benefits of investing in offense versus defense by team
